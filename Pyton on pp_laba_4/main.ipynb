# %%
import pandas as pd
import cv2
from typing import List
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('annotation.csv', delimiter=',', usecols = (0, 2), names = ('AbsPath', 'Name'))

# %%
df
# Out:
#                                                 AbsPath       Name
# 0     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear
# 1     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear
# 2     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear
# 3     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear
# 4     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear
# ...                                                 ...        ...
# 1991  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear
# 1992  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear
# 1993  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear
# 1994  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear
# 1995  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear
#
# [1996 rows x 2 columns]

# %% [markdown]
# Задание 1,2

# %%
df['Class'] = df['Name'].apply(lambda name: 0 if name == 'polarbear' else 1)

# %%
df
# Out:
#                                                 AbsPath       Name  Class
# 0     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 1     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 2     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 3     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 4     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# ...                                                 ...        ...    ...
# 1991  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1992  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1993  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1994  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1995  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
#
# [1996 rows x 3 columns]

# %% [markdown]
# Задание 3

# %%
def func(path):
  print(path)
  cv2.imread(path).shape[0]
df['Width']=df['AbsPath'].apply(func)

# %%
df['Height'] = df['AbsPath'].apply(lambda path: cv2.imread(path).shape[0])

# %%
df['Width'] = df['AbsPath'].apply(lambda path: cv2.imread(path).shape[1])

# %%
df['Depth'] = df['AbsPath'].apply(lambda path: cv2.imread(path).shape[2])

# %%
df
# Out:
#                                                 AbsPath       Name  Class  \
# 0     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 1     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 2     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 3     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 4     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# ...                                                 ...        ...    ...
# 1991  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1992  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1993  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1994  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1995  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
#
#       Height  Width  Depth
# 0       2000   3000      3
# 1       1282   1920      3
# 2       1000   1500      3
# 3       1800   2700      3
# 4       2000   3000      3
# ...      ...    ...    ...
# 1991    1024   1280      3
# 1992     593    900      3
# 1993     800    800      3
# 1994     768    768      3
# 1995    1361   1241      3
#
# [1996 rows x 6 columns]

# %% [markdown]
# Задание 4

# %%
df.describe()
# Out:
#              Class       Height        Width   Depth
# count  1996.000000  1996.000000  1996.000000  1996.0
# mean      0.499499  1194.216934  1676.642285     3.0
# std       0.500125   490.501977   726.152500     0.0
# min       0.000000   333.000000   500.000000     3.0
# 25%       0.000000   800.000000  1024.000000     3.0
# 50%       0.000000  1080.000000  1600.000000     3.0
# 75%       1.000000  1366.000000  2048.000000     3.0
# max       1.000000  3000.000000  3000.000000     3.0

# %%
df['Class'].describe().value_counts()
# Out:
# Class
# 0.000000       3
# 1.000000       2
# 1996.000000    1
# 0.499499       1
# 0.500125       1
# Name: count, dtype: int64

# %% [markdown]
# Задание 5 #сбалансированный набор данных

# %%
def filter_df(df: pd.DataFrame, class_name: int) -> pd.DataFrame:
    """
    Данная функция возвращает датафрейм, состоящий из строк, для которых значение метки соответствует заданному
    """
    new_df = df[df['Class'] == class_name]
    return new_df

# %%
df_0 = filter_df(df, 0) 
df_1 = filter_df(df, 1)

# %%
df_0
# Out:
#                                                AbsPath       Name  Class  \
# 0    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 1    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 2    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 3    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 4    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# ..                                                 ...        ...    ...
# 994  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 995  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 996  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 997  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 998  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
#
#      Height  Width  Depth
# 0      2000   3000      3
# 1      1282   1920      3
# 2      1000   1500      3
# 3      1800   2700      3
# 4      2000   3000      3
# ..      ...    ...    ...
# 994    1200   1920      3
# 995     910    910      3
# 996     644    962      3
# 997     900    900      3
# 998    1200   1920      3
#
# [999 rows x 6 columns]

# %% [markdown]
# Задание 6

# %%
def filter_df_max(df: pd.DataFrame, class_name: int, max_height: int, max_width: int) -> pd.DataFrame:
    """
    Данная функция возвращает датафрейм, для которого размеры удовлетворяют следующему условию: 
    height <= max_height and width <= max_width, а метка класса соответствует указанной.
    """
    new_df = df[(df['Class'] == class_name) & (df['Height'] <= max_height) & (df['Width'] <= max_width)]
    return new_df

# %%
df_0_filter = filter_df_max(df, 0, df['Height'].max(), df['Width'].max())
df_1_filter = filter_df_max(df, 1, df['Height'].max()-5, df['Width'].max()-5)

# %%
df_0_filter
# Out:
#                                                AbsPath       Name  Class  \
# 0    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 1    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 2    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 3    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 4    D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# ..                                                 ...        ...    ...
# 994  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 995  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 996  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 997  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 998  D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
#
#      Height  Width  Depth
# 0      2000   3000      3
# 1      1282   1920      3
# 2      1000   1500      3
# 3      1800   2700      3
# 4      2000   3000      3
# ..      ...    ...    ...
# 994    1200   1920      3
# 995     910    910      3
# 996     644    962      3
# 997     900    900      3
# 998    1200   1920      3
#
# [999 rows x 6 columns]

# %% [markdown]
# Задание 7

# %%
df['Pixels'] = df['Height'] * df['Width'] * df['Depth']
df
# Out:
#                                                 AbsPath       Name  Class  \
# 0     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 1     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 2     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 3     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# 4     D:\2 Curs(yes)\repositori on git\Programming-1...  polarbear      0
# ...                                                 ...        ...    ...
# 1991  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1992  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1993  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1994  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
# 1995  D:\2 Curs(yes)\repositori on git\Programming-1...  brownbear      1
#
#       Height  Width  Depth    Pixels
# 0       2000   3000      3  18000000
# 1       1282   1920      3   7384320
# 2       1000   1500      3   4500000
# 3       1800   2700      3  14580000
# 4       2000   3000      3  18000000
# ...      ...    ...    ...       ...
# 1991    1024   1280      3   3932160
# 1992     593    900      3   1601100
# 1993     800    800      3   1920000
# 1994     768    768      3   1769472
# 1995    1361   1241      3   5067003
#
# [1996 rows x 7 columns]

# %%
grouped = df.groupby('Class').agg({'Pixels': ['max', 'min', 'mean']})
grouped
# Out:
#          Pixels
#             max      min          mean
# Class
# 0      26676000  1080000  6.958367e+06
# 1      27000000   499500  6.860953e+06

# %% [markdown]
# Задание 8

# %%
def get_hists(df: pd.DataFrame, class_name: int) -> List[np.ndarray]:
    """
    Возвращает 3 массива значений гистограммы по каждому каналу(b, g, r)
    """
    class_df = filter_df(df, class_name)
    img = cv2.imread(class_df['AbsPath'].sample().values[0])
    hists = []
    for i in range(3):
        hist = cv2.calcHist([img], [i], None, [256], [0, 256])
        hists.append(hist)
    return hists

# %% [markdown]
# Задание 9

# %%
hists = get_hists(df, 1)
colors = ["Blue", "Green", "Red"]

for i in range(len(hists)):
    plt.plot(hists[i], color=colors[i], label=f"{colors[i]} Histogram")
    plt.xlim([0, 256])

plt.title("Histograms")
plt.xlabel('Intensity', fontsize = 13)
plt.ylabel('Density Pixels', fontsize = 13)
plt.legend()
plt.show()

# %% [markdown]
# Задание 10
